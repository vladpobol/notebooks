# %%
import numpy as np
from numpy.linalg import norm

class KNN():
    def __init__(self,k=1,count_class=2):
        self.k = k
        self.count_class = count_class
        self.centroids = []
        
    def fit(X,y):
        images = X.reshape(X.shape[0], -1)[:]
        images2 = X.reshape(X.shape[0], -1)[:] 
        
        clasters = []
        centroids = [i for i in images]  
        
        while len(centroids) > self.count_class:
            k = self.k

            for cnt in centroids:
                
                arr_norm = np.array([norm(cnt - img) for img in images])
                
                new_claster = []
                
                for i in range(k):
                    try:
                        new_claster += [image[argmin(arr_norm)][:]]
                        np.delete(arr_norm,argmin(arr_norm))
                        np.delete(images, argmin(arr_norm))
                    except:
                        break
                
            
                clasters += [[new_claster]]
                
            centroids = []
            
            for i in range(len(clasters)):
                centroids += [sum([img for img in clasters[i]])/len(clasters[i])]
                
            k += 1
        
                
                
                


            
   

                     
                
                
                clasters[ind] = new_claster
