# %%
import numpy as np
import torch
from torchvision import datasets, transforms
import os

# %%
data_dir = '../datasets/yandex/yandex_images_1'

# %%
data
# Out:
# Dataset ImageFolder
#     Number of datapoints: 9605
#     Root location: ../datasets/yandex
#     StandardTransform
# Transform: ToTensor()

# %%
image_list = []

for i in os.listdir(data_dir):
    image_list.append(data_dir+'/'+i)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 9605
#     Root location: ../datasets/yandex
#     StandardTransform
# Transform: ToTensor()

# %%
cv2.imread('../datasets/yandex/yandex_images_1/0001.png')
# Out:
# array([[ 14,  64,  85],
#        [ 16,  70,  87],
#        [ 21,  76,  97],
#        [ 20,  74, 102],
#        [ 13,  66,  90],
#        [  9,  58,  81],
#        [ 11,  59,  80],
#        [ 14,  64,  83],
#        [ 12,  62,  80],
#        [ 13,  61,  77],
#        [ 16,  59,  74],
#        [ 19,  54,  76],
#        [ 12,  55,  75],
#        [ 15,  56,  72],
#        [ 18,  57,  68],
#        [ 15,  59,  69],
#        [ 16,  53,  71],
#        [ 19,  42,  62],
#        [ 18,  47,  56],
#        [ 15,  50,  60],
#        [ 20,  56,  70],
#        [ 24,  56,  71],
#        [ 26,  53,  70],
#        [ 27,  53,  70],
#        [ 27,  55,  70],
#        [ 24,  55,  65],
#        [ 26,  55,  63],
#        [ 30,  60,  69],
#        [ 33,  66,  79],
#        [ 32,  67,  80],
#        [ 37,  70,  79],
#        [ 43,  79,  93],
#        [ 48,  89, 108],
#        [ 48,  90, 112],
#        [ 51,  90, 114],
#        [ 48,  84, 109],
#        [ 45,  84, 106],
#        [ 39,  85, 103],
# ...
